# %%
name = "Mansoor"
print(name[2])
# Out:
# n

# %%
name = "Mansoor"
print(name[-1])
# Out:
# r

# %%
name = "Mansoor"
print(name[-0])
# Out:
# M

# %%
name = "Mansoor"
print(name[-2])
# Out:
# o

# %%
name = ["Mansoor","dada",'dada']
print(name[-2])
# Out:
# dada

# %%
name = ["Mansoor","dada",'dada']
print(name[])
# Out:
#   File "<ipython-input-6-1be04d795eb0>", line 2
#     print(name[])
#                ^
# SyntaxError: invalid syntax

# %%
name = ["Mansoor","dada",'dada']
print(name[1])
# Out:
# dada

# %%
name = ["Mansoor","NANA",'dada']
print(name[1])
# Out:
# NANA

# %%
name = ["Mansoor","NANA",'dada']
print(name[1])
# Out:
# NANA

# %%
name = ("Mansoor","NANA",'dada')
print(name[1])
# Out:
# NANA

# %%
name = ("Mansoor","NANA",'dada')
print(name[2])
# Out:
# dada

# %%
name = ("Mansoor","NANA",'dada')
print(name)
# Out:
# ('Mansoor', 'NANA', 'dada')

# %%
name = (11122.33,12121.432)
print(name)
# Out:
# (11122.33, 12121.432)

# %%
name = (11122.33,12121.432)
print(name[1])
# Out:
# 12121.432

# %%
name = (11122.33,12121.432)
print(name[0])
# Out:
# 11122.33

# %%
name = (11122.33,12121.432)
print(name[2])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# d:\LocalDev\htdocs\edX Python Course\edx-python-for-web\sequences.py in <module>
#       1 name = (11122.33,12121.432)
# ----> 2 print(name[2])
#
# IndexError: tuple index out of range

# %%
name = (11122.33,12121.432)
print(pop(name))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\LocalDev\htdocs\edX Python Course\edx-python-for-web\sequences.py in <module>
#       1 name = (11122.33,12121.432)
# ----> 2 print(pop(name))
#
# NameError: name 'pop' is not defined
